# %%
import pandas as pd

# %%
data =pd.read_csv("data/ign.csv", delimiter = ',')

# %%
data.head()
# Out:
#    Unnamed: 0 score_phrase                                              title  \
# 0           0      Amazing                            LittleBigPlanet PS Vita
# 1           1      Amazing  LittleBigPlanet PS Vita -- Marvel Super Hero E...
# 2           2        Great                               Splice: Tree of Life
# 3           3        Great                                             NHL 13
# 4           4        Great                                             NHL 13
#
#                                                  url          platform  score  \
# 0             /games/littlebigplanet-vita/vita-98907  PlayStation Vita    9.0
# 1  /games/littlebigplanet-ps-vita-marvel-super-he...  PlayStation Vita    9.0
# 2                          /games/splice/ipad-141070              iPad    8.5
# 3                      /games/nhl-13/xbox-360-128182          Xbox 360    8.5
# 4                           /games/nhl-13/ps3-128181     PlayStation 3    8.5
#
# ...

# %%
data.shape
# Out:
# (18625, 11)

# %% [markdown]
# ## Indexing DataFrames with Pandas

# %%
data.iloc[0:5,:] # get five rws
# Out:
#    Unnamed: 0 score_phrase                                              title  \
# 0           0      Amazing                            LittleBigPlanet PS Vita
# 1           1      Amazing  LittleBigPlanet PS Vita -- Marvel Super Hero E...
# 2           2        Great                               Splice: Tree of Life
# 3           3        Great                                             NHL 13
# 4           4        Great                                             NHL 13
#
#                                                  url          platform  score  \
# 0             /games/littlebigplanet-vita/vita-98907  PlayStation Vita    9.0
# 1  /games/littlebigplanet-ps-vita-marvel-super-he...  PlayStation Vita    9.0
# 2                          /games/splice/ipad-141070              iPad    8.5
# 3                      /games/nhl-13/xbox-360-128182          Xbox 360    8.5
# 4                           /games/nhl-13/ps3-128181     PlayStation 3    8.5
#
# ...

# %%
## remove First columns beacuse it is irrelevant
data = data.iloc[:,1:]
data.iloc[:5]
# Out:
#   score_phrase                                              title  \
# 0      Amazing                            LittleBigPlanet PS Vita
# 1      Amazing  LittleBigPlanet PS Vita -- Marvel Super Hero E...
# 2        Great                               Splice: Tree of Life
# 3        Great                                             NHL 13
# 4        Great                                             NHL 13
#
#                                                  url          platform  score  \
# 0             /games/littlebigplanet-vita/vita-98907  PlayStation Vita    9.0
# 1  /games/littlebigplanet-ps-vita-marvel-super-he...  PlayStation Vita    9.0
# 2                          /games/splice/ipad-141070              iPad    8.5
# 3                      /games/nhl-13/xbox-360-128182          Xbox 360    8.5
# 4                           /games/nhl-13/ps3-128181     PlayStation 3    8.5
#
#         genre editors_choice  release_year  release_month  release_day
# ...

# %%
data.index
# Out:
# RangeIndex(start=0, stop=18625, step=1)

# %%
data1 = data.iloc[10:20,:]
data1.head()
# Out:
#    score_phrase                    title  \
# 10         Good  Tekken Tag Tournament 2
# 11         Good  Tekken Tag Tournament 2
# 12         Good               Wild Blood
# 13      Amazing        Mark of the Ninja
# 14      Amazing        Mark of the Ninja
#
#                                                 url       platform  score  \
# 10        /games/tekken-tag-tournament-2/ps3-124584  PlayStation 3    7.5
# 11   /games/tekken-tag-tournament-2/xbox-360-124581       Xbox 360    7.5
# 12                  /games/wild-blood/iphone-139363         iPhone    7.0
# 13  /games/mark-of-the-ninja-135615/xbox-360-129276       Xbox 360    9.0
# 14        /games/mark-of-the-ninja-135615/pc-143761             PC    9.0
#
#                 genre editors_choice  release_year  release_month  release_day
# 10           Fighting              N          2012              9           11
# 11           Fighting              N          2012              9           11
# ...

# %%
data1.loc[10:14,["score","release_year"]]
# Out:
#     score  release_year
# 10    7.5          2012
# 11    7.5          2012
# 12    7.0          2012
# 13    9.0          2012
# 14    9.0          2012

# %% [markdown]
# ## Pandas Series Objects

# %%
data['score'].head(5)
# Out:
# 0    9.0
# 1    9.0
# 2    8.5
# 3    8.5
# 4    8.5
# Name: score, dtype: float64

# %%
data[['score','release_year']].head(10)
# Out:
#    score  release_year
# 0    9.0          2012
# 1    9.0          2012
# 2    8.5          2012
# 3    8.5          2012
# 4    8.5          2012
# 5    7.0          2012
# 6    3.0          2012
# 7    9.0          2012
# 8    3.0          2012
# 9    7.0          2012

# %%
data.head(10)
# Out:
#   score_phrase                                              title  \
# 0      Amazing                            LittleBigPlanet PS Vita
# 1      Amazing  LittleBigPlanet PS Vita -- Marvel Super Hero E...
# 2        Great                               Splice: Tree of Life
# 3        Great                                             NHL 13
# 4        Great                                             NHL 13
# 5         Good                          Total War Battles: Shogun
# 6        Awful                                Double Dragon: Neon
# 7      Amazing                                       Guild Wars 2
# 8        Awful                                Double Dragon: Neon
# 9         Good                          Total War Battles: Shogun
#
#                                                  url          platform  score  \
# 0             /games/littlebigplanet-vita/vita-98907  PlayStation Vita    9.0
# 1  /games/littlebigplanet-ps-vita-marvel-super-he...  PlayStation Vita    9.0
# ...

# %%
xx = data[data['release_year'] > 2012]
xx.head(10)
# Out:
#     score_phrase                                          title  \
# 307         Good                               Strike Suit Zero
# 308      Painful                 Final Fantasy: All The Bravest
# 309         Good                               Tokyo Crash Mobs
# 310      Amazing           Ni no Kuni: Wrath of the White Witch
# 311     Mediocre        Marvel's The Avengers: Battle For Earth
# 312         Okay  Borderlands 2: Sir Hammerlock's Big Game Hunt
# 335         Okay  Borderlands 2: Sir Hammerlock's Big Game Hunt
# 336         Okay  Borderlands 2: Sir Hammerlock's Big Game Hunt
# 337        Great                             DmC: Devil May Cry
# 338        Great                               Unchained Blades
#
#                                                    url       platform  score  \
# 307                  /games/strike-suit-zero/pc-115112             PC    7.5
# 308  /games/final-fantasy-all-the-bravest-156962/ip...         iPhone    2.5
# ...

# %% [markdown]
# ## Pandas Plotting

# %%
data[data["platform"] == "Xbox One"]["score"].plot(kind="pie")

# %%
data[data["platform"] == "PC"]["score"].plot(kind="hist",title = "HistoGram")
